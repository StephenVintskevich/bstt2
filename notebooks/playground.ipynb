# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os, sys
DRIVE_ROOT = "/content/drive/MyDrive/DynamicsTensors"
REPO_ROOT  = f"{DRIVE_ROOT}/bstt2"
DATA_DIR   = f"{DRIVE_ROOT}/data"
OUT_DIR    = f"{DRIVE_ROOT}/outputs"

EXP = "basetests"
RUN_DIR = f"{OUT_DIR}/{EXP}"

os.makedirs(RUN_DIR, exist_ok=True)
if REPO_ROOT not in sys.path: sys.path.append(REPO_ROOT)

print("Repo:", REPO_ROOT)
print("Data:", DATA_DIR)
print("Run dir:", RUN_DIR)
# Out:
# Repo: /content/drive/MyDrive/DynamicsTensors/bstt2
# Data: /content/drive/MyDrive/DynamicsTensors/data
# Run dir: /content/drive/MyDrive/DynamicsTensors/outputs/basetests

# %%
# Uploading orginal bsst modules
from misc import  __block, sinecosine_measures, random_homogenous_polynomial_sum_system2,random_fixed_variable_sum_system2,legendre_measures
from helpers import magneticDipolesSamples, SMat
from als import ALSSystem2
from bstt import Block, BlockSparseTensor, BlockSparseTT
block = __block()
######################
# Import Standard libs
from time import time as clock
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### Class Block

# %%
# Reproduce paper's examples here:
# Block is object the describes subdomain of indeces === Block is a region specifier for indices of some tensor
# If you treat a tensor as a function on a discrete index set, a Block is just a way to specify a subdomain of that function.
# The Class Block contains methods: to check multidimensional alighment of regions:
# disjoint == True if at least one axis is not alighned, coherent - no partial overlap, contains - one region inside another region

#1 note input is a slice object collected in tuple:
BlA = Block((slice(0,4),slice(2,6)))
BlA1 = Block((slice(0,4),slice(2,6)))
BlB = Block((slice(0,6),slice(2,9)))
BlC = Block((slice(0,2),slice(2,6), slice(11,17)))
# check ('ask' about contains)
print(BlA.disjoint(BlA1))
print(BlA.coherent(BlA1))
print(BlA.contains(BlA1))
print(BlA.contains(BlB))
print(BlB.contains(BlA))
########################
# Out:
# False
# True
# True
# False
# True

# %%
# one can print (usful for users the Block object)
print(BlA)
#### can not compare subdomains of different Blocks! (you will see assertion error)
#print(BlC.contains(BlA))
# one can also get properties of Block object:
BlA.shape
BlB.size
# Out:
# (0:4, 2:6)
# np.int64(42)

# %% [markdown]
# ### Class BlockSparseTensor

# %%
# One creates Tensor X with some shape: (n0,...nd). It is zero everywhere except final collection of blocks
# To instantiate it you must provide: data with _data.shape = sum(B_{m}) to enocde data in blocks
